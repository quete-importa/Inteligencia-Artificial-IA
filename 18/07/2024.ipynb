# %% [markdown]
# <a href="https://colab.research.google.com/github/quete-importa/Inteligencia-Artificial-IA/blob/main/18/07/2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(pd.__version__)

serieData=pd.Series(data=[100,200,300], index=['fernando', 'pedro', 'lucas'])
print(serieData)

print(serieData['fernando'])

print (serieData.index)

print('fernando' in serieData)
# Out:
# 2.0.3
# fernando    100
# pedro       200
# lucas       300
# dtype: int64
# 100
# Index(['fernando', 'pedro', 'lucas'], dtype='object')
# True

# %%
import pandas as pd

myDiccionario = {
    'one': pd.Series([100, 200, 300], index=['fernando', 'pedro', 'lucas']),
    'two': pd.Series([11, 12, 33], index=['julio', 'pedro', 'lucas'])
}

# SERIES Y DATAFRAMES
df = pd.DataFrame(myDiccionario)
print(df)

print(df.index)
print(df)
print('we are here............')
print(df.index)
print(df.columns)

print(df['two']['julio'])
# Out:
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# we are here............
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# 11.0

# %%
import pandas as pd
df = pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(6)
# Out:
#        movieId                           title                  genres
# 62417   209155      Santosh Subramaniam (2008)   Action|Comedy|Romance
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
del df['genres']

# %%
df
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
df.shape
# Out:
# (62423, 2)

# %%
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp=df.iloc[255]

# %%
tmp
# Out:
# movieId                                     258
# title      Kid in King Arthur's Court, A (1995)
# Name: 255, dtype: object

# %%
tmp['movieId']
# Out:
# 255    258
# 256    259
# 257    260
# Name: movieId, dtype: int64

# %%
'rating' in df.columns
# Out:
# False

# %%
tmp=df.iloc[[255,256,257]]

# %%
tmp
# Out:
#      movieId                                      title
# 255      258       Kid in King Arthur's Court, A (1995)
# 256      259                       Kiss of Death (1995)
# 257      260  Star Wars: Episode IV - A New Hope (1977)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
min_movieid = df['movieId'].min()
max_movieid = df['movieId'].max()
mean_movieid = df['movieId'].mean()

print("Valor mínimo de movieId:", min_movieid)
print("Valor máximo de movieId:", max_movieid)
print("Valor promedio de movieId:", mean_movieid)
# Out:
# Valor mínimo de movieId: 1
# Valor máximo de movieId: 209171
# Valor promedio de movieId: 122220.38764557935

# %%
movies=pd.read_csv('/content/movies.csv')
ratings=pd.read_csv('/content/ratings.csv')
tags=pd.read_csv('/content/tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
tags.head()

# %%
del.ratings['timestamp']

# %%
del.tags['timestamp']

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
print(tags.shape)
aux1 = tags.shape[0]
tags = tags.dropna()
aux2 = tags.shape[0]
print(aux1)
print(tags.shape)
print(f'Muestras eliminadas en variable tag: {aux1 - aux2}')
# Out:
# (1093360, 4)
# 1093360
# (1093344, 4)
# Muestras eliminadas en variable tag: 16

# %%
print(ratings.columns)
print(ratings['rating'].max())
print(ratings['rating'].min())

calificacion_alta=ratings['rating']>=4
calificacion_baja=ratings['rating']<=2
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# 5.0
# 0.5

# %%
calificacion_alta.shape
# Out:
# (778728,)

# %%
ratings[calificacion_alta]
print('numero de muestras despues del filtro',ratings_despues.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-26338c380846> in <cell line: 2>()
#       1 ratings[calificacion_alta]
# ----> 2 print('numero de muestras despues del filtro',ratings_despues.shape)
#
# NameError: name 'ratings_despues' is not defined
