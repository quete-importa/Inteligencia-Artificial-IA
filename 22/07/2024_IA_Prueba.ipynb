# %% [markdown]
# <a href="https://colab.research.google.com/github/quete-importa/Inteligencia-Artificial-IA/blob/main/22/07/2024_IA_Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
df
# Out:
#          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]

# %%
# prompt:
# para una exploración básica, sugerimos utilizar los módulos shape, head(), tail(), dtypes, type()

# 1. Importa pandas como pd y carga el conjunto de datos
# Usa esta línea para cargar el conjunto de datos.
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

# Exploración Básica
# Primero, echemos un vistazo rápido a cómo se ven estos datos.
print("Shape of the DataFrame:", df.shape)         # Muestra la forma del DataFrame (número de filas y columnas)
print("\nFirst 5 rows of the DataFrame:\n", df.head())  # Muestra las primeras 5 filas del DataFrame
print("\nLast 5 rows of the DataFrame:\n", df.tail())   # Muestra las últimas 5 filas del DataFrame
print("\nData types of each column:\n", df.dtypes)     # Muestra los tipos de datos de cada columna
print("\nType of the DataFrame object:", type(df))     # Muestra el tipo del objeto DataFrame
# Out:
# Shape of the DataFrame: (1145586, 5)
#
# First 5 rows of the DataFrame:
#     station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499
#
# Last 5 rows of the DataFrame:
#           station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# Data types of each column:
#  station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object
#
# Type of the DataFrame object: <class 'pandas.core.frame.DataFrame'>

# %%
df.describe()
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %%
print(df['rides'].min())
print(df['rides'].max())
# Out:
# 0
# 36323

# %%
import pandas as pd
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

print(df.head())
# Out:
#             station_id       stationname daytype  rides
# date
# 2017-12-22       41280    Jefferson Park       W   6104
# 2017-12-18       41000  Cermak-Chinatown       W   3636
# 2017-12-02       40280      Central-Lake       A   1270
# 2017-12-19       40140   Dempster-Skokie       W   1759
# 2017-12-03       40690          Dempster       U    499

# %%
# hint, sort_values(by='date')

df_sorted = df.sort_values(by='date')
print(df_sorted.head())
# Out:
#         station_id       stationname        date daytype  rides
# 417458       40900            Howard  01/01/2001       U   2068
# 620368       40310    Western-Orange  01/01/2001       U    460
# 284334       40070  Jackson/Dearborn  01/01/2001       U    649
# 918791       40910     63rd-Dan Ryan  01/01/2001       U   1366
# 316949       40330       Grand/State  01/01/2001       U   2542

# %%
# hint, use filter like this df['stationname']=='Garfield-South Elevated']
# use the following variable name for your specific stations
#Garfield_South_Elevated=pd.DataFrame()

# Filtrar los datos para la estación 'Garfield-South Elevated'
Garfield_South_Elevated = df_sorted[df_sorted['stationname'] == 'Garfield-South Elevated']

# Verificar los datos filtrados
print("Datos para Garfield-South Elevated:")
print(Garfield_South_Elevated.head(10))
# Out:
# Datos para Garfield-South Elevated:
#          station_id              stationname        date daytype  rides
# 424117        40510  Garfield-South Elevated  01/01/2001       U    248
# 1021950       40510  Garfield-South Elevated  01/01/2002       U    305
# 1092906       40510  Garfield-South Elevated  01/01/2003       U    343
# 283802        40510  Garfield-South Elevated  01/01/2004       U    449
# 549409        40510  Garfield-South Elevated  01/01/2005       U    386
# 793180        40510  Garfield-South Elevated  01/01/2006       U    386
# 662597        40510  Garfield-South Elevated  01/01/2007       U    490
# 770444        40510  Garfield-South Elevated  01/01/2008       U    469
# 588283        40510  Garfield-South Elevated  01/01/2009       U    448
# 270686        40510  Garfield-South Elevated  01/01/2010       U    477

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)

Garfield_Dan_Ryan = df_sorted[df_sorted['stationname'] == 'Garfield-Dan Ryan']
Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_South_Elevated['rides'].plot(linewidth=0.5)

Garfield_South_Elevated = df_sorted[df_sorted['stationname'] == 'Garfield-South Elevated']
Garfield_South_Elevated['rides'].plot(linewidth=0.5)
# Out:
# <Axes: >
